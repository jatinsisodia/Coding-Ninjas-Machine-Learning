# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[2,5,6]
plt.scatter(x,y)
plt.show()

# %%
x=[1,2,3]
y=[2,5,6]
x2=[3,4,5]
y2=[1,5,6]
plt.plot(x2,y2,"r-.")
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Plot function x^3

# %%
import numpy as np
#x=np.array([1,2,3,4])
x=np.arange(0,5,0.1)
# to make the line smooth
y=x**3
plt.plot(x,y,"bo")
plt.show()

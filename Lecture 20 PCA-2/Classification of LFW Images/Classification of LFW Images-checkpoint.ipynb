# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn import ensemble
import time

# %%
lfw=datasets.fetch_lfw_people(min_faces_per_person=100,resize=0.4)
# Out:
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976012
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976009
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976006
# Downloading LFW data (~200MB): https://ndownloader.figshare.com/files/5976015
# C:\Users\anura_000\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# C:\Users\anura_000\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
lfw.keys()
lfw.data.shape
# Out:
# (1140, 1850)

# %%
fig=plt.figure(figsize=(8,8))

# %%
for i in range(64):
    ax=fig.add_subplot(8,8,i+1)
    ax.imshow(lfw.images[i],cmap=plt.cm.bone)

# %%
plt.show()

# %%
x,y=lfw.data,lfw.target
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
pca_oliv=PCA()
pca_oliv.fit(x_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
k=0
total=0
while total<0.99:
    total=total+pca_oliv.explained_variance_ratio_[k]
    k=k+1
k
# Out:
# 316

# %%
pca_lfw=PCA(n_components=k,whiten=True)
x_transformed=pca_lfw.fit_transform(x_train)
x_transformed.shape
# Out:
# (855, 316)

# %%
x_approx=pca_lfw.inverse_transform(x_transformed)
x_approx=x_approx.reshape(855,50,37)

# %%
fig=plt.figure(figsize=(8,8))
for i in range(64):
    ax=fig.add_subplot(8,8,i+1)
    ax.imshow(x_approx[i],cmap=plt.cm.bone)
plt.show()

# %%
pca_lfw.components_.shape
# Out:
# (316, 1850)

# %%
eigenv=pca_lfw.components_.reshape(k,50,37)

# %%
fig=plt.figure(figsize=(8,8))

# %%
for i in range(64):
    ax=fig.add_subplot(8,8,i+1,xticks=[],yticks=[])
    ax.imshow(eigenv[i],cmap=plt.cm.bone)

# %%
plt.show()

# %%
x_train_pca=x_transformed
x_test_pca=pca_lfw.transform(x_test)

# %%
rf=ensemble.RandomForestClassifier()

# %%
start=time.time()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print(time.time()-start)
# Out:
# 37.18659949302673

# %%
y_pred=rf.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.68      0.70      0.69        61
#           1       0.65      0.31      0.42        36
#           2       0.59      0.89      0.71       122
#           3       0.83      0.16      0.27        31
#           4       0.43      0.17      0.24        35
#
# avg / total       0.62      0.61      0.56       285

# %%
rf=ensemble.RandomForestClassifier()

# %%
start=time.time()
rf.fit(x_train_pca,y_train)
print(time.time()-start)
# Out:
# 0.1551041603088379

# %%
y_pred=rf.predict(x_test_pca)

# %%
print(classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.49      0.41      0.45        61
#           1       0.50      0.14      0.22        36
#           2       0.51      0.89      0.65       122
#           3       0.00      0.00      0.00        31
#           4       0.10      0.03      0.04        35
#
# avg / total       0.40      0.49      0.41       285

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 25   0  35   0   1]
#  [  7   5  19   1   4]
#  [ 10   1 109   0   2]
#  [  2   3  24   0   2]
#  [  7   1  25   1   1]]
